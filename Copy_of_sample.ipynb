# %% [markdown]
# <a href="https://colab.research.google.com/github/HemanthKumarA12/Natual_language_Processing/blob/master/Copy_of_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# welcome to my python class. Happy learning

# %%
print('hello welcome to oython class')
# Out:
# hello welcome to oython class

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30
