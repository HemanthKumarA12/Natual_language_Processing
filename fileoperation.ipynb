# %% [markdown]
# <a href="https://colab.research.google.com/github/HemanthKumarA12/Natual_language_Processing/blob/master/fileoperation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile test.txt
# hello, this is hemanth kumar from  mandya
# am going to teach you some python tricks
# Out:
# Overwriting test.txt

# %%
myfile= open('test.txt')

# %%
myfile
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='UTF-8'>

# %%
pwd
# Out:
# '/content'

# %%
myfile.read()
# Out:
# 'hello, this is hemanth kumar from  mandya\nam going to teach you some python tricks '

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['hello, this is hemanth kumar from  mandya\n',
#  'am going to teach you some python tricks ']

# %%
myfile.close()

# %%
myfile=open('test.txt', 'w+')

# %%
myfile.write('this is a new first line, please come to my class on 2020 without fail')
# Out:
# 70

# %%
myfile.readlines()
# Out:
# []

# %%
myfile.seek(0)
myfile.read()
# Out:
# 'this is a new first line, please come to my class on 2020 without fail'

# %%
myfile.close()

# %%
with open('test.txt', 'r') as txt:
  first_line= txt.readlines()

print(first_line)
# Out:
# ['this is a new first line, please come to my class on 2020 without fail']

# %%
with open('test.txt' , 'r') as txt:
  for line in txt:
    print(line, end='')
# Out:
# this is a new first line, please come to my class on 2020 without fail
